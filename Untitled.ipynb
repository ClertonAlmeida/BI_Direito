# %%
import pandas as pd
dados = pd.read_csv("legal_claims.csv")

# %%
dados.head(100)
# Out:
#                LAWSUIT NUMBER   AREA  STATUS PLAINTIFF OR DEFENDANT  \
# 0   0000000-00.2010.0.00.0094    TAX  CLOSED              DEFENDANT
# 1   0000000-00.2011.0.00.0086    TAX  ACTIVE              DEFENDANT
# 2   0000000-00.2012.0.00.0092    TAX  ACTIVE              DEFENDANT
# 3   0000000-00.2013.0.00.0096    TAX  CLOSED              DEFENDANT
# 4   0000000-00.2014.0.00.0097    TAX  CLOSED              DEFENDANT
# ..                        ...    ...     ...                    ...
# 93  0000000-00.2020.0.00.0023  LABOR  ACTIVE              DEFENDANT
# 94  0000000-00.2020.0.00.0057  LABOR  ACTIVE              DEFENDANT
# 95  0000000-00.2020.0.00.0010  LABOR  ACTIVE              DEFENDANT
# 96  0000000-00.2020.0.00.0059  LABOR  ACTIVE              DEFENDANT
# 97  0000000-00.2020.0.00.0073  LABOR  ACTIVE              DEFENDANT
#
#    CONTRACT TYPE      COMPANY    SUPPLIER NAME         TYPE OF POSITION  \
# 0              -  RED CHICKEN              NaN                      NaN
# ...

# %%
dados.isnull().sum()
# Out:
# LAWSUIT NUMBER             0
# AREA                       0
# STATUS                     0
# PLAINTIFF OR DEFENDANT     0
# CONTRACT TYPE              0
# COMPANY                    0
# SUPPLIER NAME             16
# TYPE OF POSITION          16
# CITY SUBSIDIARIES          0
# PHASE                      0
# ADMISSION DATE            16
# DISMISSAL DATE            16
# ID PLANTIFF'S LAWYER      16
# CLAIM START DATE           0
# CLOSE DATE                84
# CLAIM AMOUNT               0
# AMOUNT PAID               84
#  PROVISION VALUE           0
#  RISK VALUE               14
# RISK                       0
# TYPE OF CLOSING CLAIM     84
# dtype: int64

# %%
dados['RISK'].unique()
# Out:
# array([' R$ -   ', 'MEDIUM', 'LOW', 'HIGH'], dtype=object)
